# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_original = pd.read_csv('../train.csv')

df = df_original.copy()

# %%
sns.countplot(x="street", data=df, order=df['street'].unique().sort())
# Out:
# <Axes: xlabel='street', ylabel='count'>
