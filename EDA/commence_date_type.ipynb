# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_original = pd.read_csv('../train.csv')

df = df_original.copy()

# %%
plt.figure(figsize=(14, 7))
sns.histplot(x="commence_date", y="price", data=df, hue='type', hue_order=df['type'].unique().sort())
# Out:
# <Axes: xlabel='commence_date', ylabel='price'>

# %%
sns.jointplot(x='commence_date', y='price', data=df, hue='type')
