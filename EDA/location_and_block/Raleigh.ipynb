# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_original = pd.read_csv('../../train.csv')

df = df_original.copy()
df.drop(['house_id'], axis=1)
# Out:
#            date   location       type block                  street  \
# 0       2006-09    Raleigh     5 ROOM  107D          Agawan Court
# 1       2007-06     Fresno     3 ROOM   678                 Cleo St
# 2       2010-09     Tucson     4 ROOM     5     E Pleasant View Way
# 3       2007-04     Austin     4 ROOM   326          Park Hollow Ln
# 4       2001-10   Honolulu     4 ROOM   794       Ala Puawa Place
# ...         ...        ...        ...   ...                     ...
# 271716  2003-01      Omaha     4 ROOM   483               Sandra Ln
# 271717  2000-11      Omaha     5 ROOM   615                Atkin Rd
# 271718  2011-04     Boston     5 ROOM   390        Kempton Street
# 271719  2010-09     Fresno     4 ROOM   968        Magnolia Dale Dr
# 271720  2007-10  Milwaukee  EXECUTIVE   341  W Fond du Lac Avenue
#
#        storey_range  area_sqm flat_model  commence_date     price
# 0          07 TO 09     110.0          D           2003  313000.0
# ...

# %%
df['location'].unique()
# Out:
# array(['Raleigh', 'Fresno', 'Tucson', 'Austin', 'Honolulu', 'Riverside',
#        'Omaha', 'Washington', 'Albuquerque', 'Chicago', 'Tampa',
#        'Milwaukee', 'Arlington', 'Pittsburgh', 'Boston', 'Sacramento',
#        'Seatle', 'Miami', 'Minneapolis', 'Cleveland', 'Denver', 'Mesa',
#        'Oakland', 'Atlanta', 'Portland', 'Baltimore'], dtype=object)

# %%
Raleigh_df = df[df['location'] == 'Raleigh']
Raleigh_df
# Out:
#         house_id     date location       type block               street  \
# 0         199577  2006-09  Raleigh     5 ROOM  107D       Agawan Court
# 10        339022  2012-02  Raleigh     5 ROOM   181       Agawan Court
# 369       244712  2008-07  Raleigh     5 ROOM  175C        Argonne Way
# 448       253420  2008-11  Raleigh     4 ROOM  641A    Cedar Rail Road
# 551       228522  2007-11  Raleigh  EXECUTIVE   188  Whittington Drive
# ...          ...      ...      ...        ...   ...                  ...
# 271377    283335  2009-12  Raleigh     5 ROOM  173D        Argonne Way
# 271515    336143  2011-12  Raleigh     5 ROOM  175A        Argonne Way
# 271525    217508  2007-06  Raleigh     5 ROOM  128D     Sagacity Drive
# 271595    269907  2009-07  Raleigh     5 ROOM  174D       Holly Circle
# 271678    274865  2009-09  Raleigh     5 ROOM  642D    Cedar Rail Road
#
#        storey_range  area_sqm flat_model  commence_date     price
# ...

# %%
plt.figure(figsize=(14, 7))
sns.histplot(x="area_sqm", y="price", data=Raleigh_df, hue='type', hue_order=df['type'].unique().sort())
# Out:
# <Axes: xlabel='area_sqm', ylabel='price'>

# %%
plt.figure(figsize=(14, 7))
sns.histplot(x="area_sqm", y="price", data=Raleigh_df, hue='street', hue_order=df['street'].unique().sort())
# Out:
# <Axes: xlabel='area_sqm', ylabel='price'>

# %%
sns.pairplot(Raleigh_df, hue='type')

# %%
sns.pairplot(Raleigh_df, hue='flat_model')
